# %%
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# - Import relevant python libraries necessary for Python and Pandas analysis, as well as visualization
# - Import the CSV file NSMES1988updated.csv file and create a new dataframe for working with Pandas and run standard EDA(describe, shape, info, etfc..)
# - Pick 4 columns to build a histogram grid (using subplots)
# - Compare distribution using box plots for health and region columns (a chart for each)

# %%
df = pd.read_csv('./NSMES1988updated.csv')
df.head()
df.columns
# df.shape
# Out:
# Index(['visits', 'nvisits', 'ovisits', 'novisits', 'emergency', 'hospital',
#        'health', 'chronic', 'adl', 'region', 'age', 'afam', 'gender',
#        'married', 'school', 'income', 'employed', 'insurance', 'medicaid'],
#       dtype='object')

# %%
# visits, income, insurance, health

# %%
fig = plt.figure(figsize=(12,7))
# plt.xticks(rotation=45)
sns.boxplot(x=df['visits'], y=df['health'], palette="flare", hue=df['health'])
# Out:
# <Axes: xlabel='visits', ylabel='health'>

# %%
sns.boxplot(x=df['visits'], y=df['region'], palette="flare", hue=df['region'])
# Out:
# <Axes: xlabel='visits', ylabel='region'>

# %%
sns.boxplot(x=df['visits'], y=df['gender'], palette="flare", hue=df['gender'])
# Out:
# <Axes: xlabel='visits', ylabel='gender'>

# %%
sns.boxplot(x=df['visits'], y=df['insurance'], palette="flare", hue=df['insurance'])
# Out:
# <Axes: xlabel='visits', ylabel='insurance'>
